# %%
import pandas as pd
from statsmodels.tsa.stattools import grangercausalitytests

# Upload Data in a DataFrame
data = pd.read_csv('./datasets/US data - quarterly.csv', parse_dates=['date'])
data = data[data['date'] >= '1973-04-01']
data.set_index(['date'], inplace=True)
data
# Out:
#             co2, total  consumption, fossil fuel  consumption, nuclear  \
# date
# 1973-04-01    1191.325                 17.700926              0.201198
# 1973-07-01    1105.705                 16.465586              0.211969
# 1973-10-01    1132.106                 16.890961              0.252578
# 1974-01-01    1267.861                 18.854998              0.261185
# 1974-04-01    1144.458                 17.021725              0.268109
# ...                ...                       ...                   ...
# 2016-04-01    1226.615                 18.886686              2.034472
# 2016-07-01    1274.282                 19.131206              2.134695
# 2016-10-01    1294.103                 19.344535              2.067827
# 2017-01-01    1369.789                 20.820758              2.195990
# 2017-04-01    1215.585                 18.637153              1.939067
#
#             consumption, primary  consumption, renewable  gdp chained  \
# date
# 1973-04-01             19.055534                1.141531       5441.5
# 1973-07-01             17.826532                1.136698       5411.9
# 1973-10-01             18.140034                0.984216       5462.4
# 1974-01-01             20.309980                1.181978       5417.0
# 1974-04-01             18.546133                1.245739       5431.3
# ...                          ...                     ...          ...
# 2016-04-01             23.643264                2.673412      16663.5
# 2016-07-01             23.952314                2.623535      16778.1
# 2016-10-01             23.909773                2.440118      16851.4
# 2017-01-01             25.747186                2.671027      16903.2
# 2017-04-01             23.491092                2.865524      17031.1
#
#             production, fossil fuel  production, nuclear  production, primary  \
# date
# 1973-04-01                14.392755             0.201198            15.735483
# 1973-07-01                14.421367             0.211969            15.770034
# 1973-10-01                14.771822             0.252578            16.008617
# 1974-01-01                14.651743             0.261185            16.094904
# 1974-04-01                14.226263             0.268109            15.740110
# ...                             ...                  ...                  ...
# 2016-04-01                15.932351             2.034472            20.663655
# 2016-07-01                16.251261             2.134695            21.015921
# 2016-10-01                16.642803             2.067827            21.155633
# 2017-01-01                16.625131             2.195990            21.523741
# 2017-04-01                16.319906             1.939067            21.156485
#
#             production, renewable
# date
# 1973-04-01               1.141531
# 1973-07-01               1.136698
# 1973-10-01               0.984216
# 1974-01-01               1.181978
# 1974-04-01               1.245739
# ...                           ...
# 2016-04-01               2.696830
# 2016-07-01               2.629965
# 2016-10-01               2.445001
# 2017-01-01               2.702619
# 2017-04-01               2.897513
#
# [177 rows x 10 columns]

# %%
from itertools import combinations

maxlag = 20 # theoretical max: 58 -- apply max 20 (5 years)
p_val_max = 0.01

for indicator1, indicator2 in list(combinations(data.columns, r=2)):

    results = []

    for var_caused, var_cause in [(indicator1, indicator2), (indicator2, indicator1)]:
        gct = grangercausalitytests(data[[var_caused, var_cause]], maxlag=maxlag, verbose=False)

        min_p = None
        min_lag = None

        for lag, test in gct.items():
            chi2, p, _, _ = test[0]['params_ftest']

            if min_p == None or p < min_p:
                min_p = p
                min_lag = lag

        results.append({'p':min_p, 'lag':min_lag})

    if results[0]['p'] < p_val_max and results[1]['p'] < p_val_max:
        print(indicator1, "<-->", indicator2, ":", results[0]['lag'], results[1]['lag'])
    elif results[0]['p'] < p_val_max and results[1]['p'] >= p_val_max:
        print(indicator1, "<---", indicator2, ":", results[0]['lag'])
    elif results[0]['p'] >= p_val_max and results[1]['p'] < p_val_max:
        print(indicator1, "--->", indicator2, ":", results[1]['lag'])
    else:
        print(indicator1, "--/--", indicator2)
# Out:
# co2, total <--> consumption, fossil fuel : 3 3
# co2, total <--> consumption, nuclear : 3 3
# co2, total <--> consumption, primary : 2 2
# co2, total <--> consumption, renewable : 3 3
# co2, total <--- gdp chained : 4
# co2, total <--> production, fossil fuel : 2 6
# co2, total <--> production, nuclear : 3 3
# co2, total <--> production, primary : 3 2
# co2, total <--> production, renewable : 3 3
# consumption, fossil fuel <--> consumption, nuclear : 3 3
# consumption, fossil fuel <--> consumption, primary : 3 3
# consumption, fossil fuel <--> consumption, renewable : 3 3
# consumption, fossil fuel <--- gdp chained : 4
# consumption, fossil fuel <--> production, fossil fuel : 2 2
# consumption, fossil fuel <--> production, nuclear : 3 3
# consumption, fossil fuel <--> production, primary : 3 2
# consumption, fossil fuel <--> production, renewable : 3 3
# consumption, nuclear <--> consumption, primary : 3 3
# consumption, nuclear <--> consumption, renewable : 3 3
# consumption, nuclear <--> gdp chained : 1 13
# consumption, nuclear <--> production, fossil fuel : 3 4
# consumption, nuclear <--> production, nuclear : 5 5
# consumption, nuclear ---> production, primary : 4
# consumption, nuclear <--> production, renewable : 3 3
# consumption, primary <--> consumption, renewable : 3 3
# consumption, primary <--- gdp chained : 1
# consumption, primary <--> production, fossil fuel : 2 5
# consumption, primary <--> production, nuclear : 3 3
# consumption, primary <--> production, primary : 3 2
# consumption, primary <--> production, renewable : 3 3
# consumption, renewable <--- gdp chained : 1
# consumption, renewable <--> production, fossil fuel : 3 2
# consumption, renewable <--> production, nuclear : 3 3
# consumption, renewable <--> production, primary : 3 3
# consumption, renewable <--> production, renewable : 2 2
# gdp chained ---> production, fossil fuel : 2
# gdp chained <--> production, nuclear : 13 1
# gdp chained ---> production, primary : 2
# gdp chained ---> production, renewable : 1
# production, fossil fuel <--> production, nuclear : 4 3
# production, fossil fuel ---> production, primary : 3
# production, fossil fuel <--> production, renewable : 2 3
# production, nuclear ---> production, primary : 4
# production, nuclear <--> production, renewable : 3 3
# production, primary <--> production, renewable : 3 3
